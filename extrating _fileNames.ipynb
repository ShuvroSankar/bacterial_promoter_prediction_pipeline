# %%
from pathlib import Path
folder_path = Path("/Users/shuvrosankar/Downloads/predictions_bacteria_final")

files = [f.name for f in folder_path.iterdir() if f.is_file()]

# Join all names with a newline character and save at once
Path('my_file_list.txt').write_text('\n'.join(files), encoding='utf-8')
# Out:
# 449554
